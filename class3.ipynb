# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt

image1 = cv2.imread('picture/test111.jpg')
gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
image2 = cv2.imread('picture/test111.jpg',cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))

# %%
image3 = cv2.imread('picture/test111.jpg',cv2.IMREAD_COLOR)

plt.imshow(image3)

# %%
image4 = cv2.imread('picture/test111.jpg',0)

plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
image5 = cv2.imread('picture/test111.jpg')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[ 78,  78,  75, ..., 114, 114, 113],
#        [ 82,  77,  78, ..., 115, 114, 114],
#        [ 77,  79,  76, ..., 115, 114, 114],
#        ...,
#        [ 60,  64,  69, ...,  45,  45,  45],
#        [ 63,  66,  71, ...,  45,  45,  46],
#        [ 64,  66,  71, ...,  46,  45,  45]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
image6 = cv2.imread('picture/test111.jpg')
b,g,r = cv2.split(image6)
img = cv2.merge((r,g,b))
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
b,g,r = cv2.split(image1)
img = cv2.merge((r,g,b))
plt.imshow(img)
