# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt

image1 = cv2.imread('picture/test111.jpg')
gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
image2 = cv2.imread('picture/test111.jpg',cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))

# %%
image3 = cv2.imread('picture/panda1.jpg',cv2.IMREAD_COLOR)

plt.imshow(image3)

# %%
image4 = cv2.imread('picture/panda1.jpg',0)

plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
image5 = cv2.imread('picture/panda1.jpg')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[23, 24, 24, ..., 37, 37, 37],
#        [24, 24, 24, ..., 37, 37, 37],
#        [24, 24, 24, ..., 37, 37, 37],
#        ...,
#        [22, 22, 22, ...,  8,  9,  9],
#        [22, 22, 21, ...,  7,  8,  8],
#        [27, 26, 25, ...,  7,  7,  7]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
image6 = cv2.imread('picture/panda1.jpg')
b,g,r = cv2.split(image6)
img = cv2.merge((r,g,b))
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
b,g,r = cv2.split(image1)
img = cv2.merge((r,g,b))
plt.imshow(img)
